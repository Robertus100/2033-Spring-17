# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot([1,2,4,9,16]);

# %%
plt.plot([0,1,2],[0,1,4],"rd-")

# %%
import numpy as np
x = np.linspace(0, 10, 20)
y1 = x**2
y2 = x**1.5
plt.plot(x, y1, "bo-", linewidth=2, markersize=12, label="First");
plt.plot(x, y2, "gs-", linewidth=2, markersize=12, label="Second");
plt.xlabel("$X$");
plt.ylabel("$Y$");
plt.axis([-0.5, 10.5, -5, 105])
plt.legend(loc="upper left");

# %%
x=np.logspace(0,1,10) 
y=x**2 
plt.loglog(x,y,"bo-")

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(size=1000)
plt.hist(x);

# %%
plt.hist(x, normed=True, bins=np.linspace(-5, 5, 21));

# %%
x = np.random.gamma(2,3,10000)
plt.figure()
plt.subplot(221)
plt.hist(x, bins=30)
plt.subplot(222)
plt.hist(x, bins=30, normed = True)
plt.subplot(223)
plt.hist(x, bins=30, cumulative = 30)
plt.subplot(224)
plt.hist(x, bins=30, cumulative = True, histtype = "step")
# Out:
# (array([   586.,   1770.,   3056.,   4285.,   5399.,   6370.,   7172.,
#           7849.,   8364.,   8757.,   9080.,   9300.,   9494.,   9633.,
#           9730.,   9800.,   9847.,   9894.,   9927.,   9954.,   9964.,
#           9977.,   9983.,   9991.,   9995.,   9995.,   9998.,   9998.,
#           9999.,  10000.]),
#  array([  0.05672751,   1.14780459,   2.23888168,   3.32995877,
#           4.42103586,   5.51211294,   6.60319003,   7.69426712,
#           8.78534421,   9.87642129,  10.96749838,  12.05857547,
#          13.14965256,  14.24072964,  15.33180673,  16.42288382,
#          17.51396091,  18.60503799,  19.69611508,  20.78719217,
#          21.87826926,  22.96934634,  24.06042343,  25.15150052,
#          26.24257761,  27.33365469,  28.42473178,  29.51580887,
#          30.60688596,  31.69796304,  32.78904013]),
#  <a list of 1 Patch objects>)
